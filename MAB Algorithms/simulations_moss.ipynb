# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from policy_evaluator_moss import policy_evaluator_moss_min

# %% [markdown]
# In this notebook, we implement the policy evaluator for finite data stream (https://arxiv.org/pdf/1003.5956.pdf) for the MOSS algorithm

# %% [markdown]
# First, we import the data

# %%
data = pd.read_csv('../Data/dataset_1000_minimum_reviews.csv', index_col='Unnamed: 0')
df = data[['time', 'movie_id', 'user_id', 'binary_rating']]
df.head()
# Out:
#    time  movie_id  user_id  binary_rating
# 0     0      1197     3669              0
# 1     1       780     3621              0
# 2     2      1234     4917              0
# 3     3      1544     1147              0
# 4     4      3175      262              1

# %%
payoffs = policy_evaluator_moss_min(df)

# %%
cumulative_average = np.cumsum(payoffs) / np.arange(1, len(payoffs)+1)

plt.plot(cumulative_average)
plt.xlabel("Time")
plt.ylabel("Cumulative Average")
plt.title("Cumulative Average of the payoffs for Moss Algorithm")
plt.ylim(0, 1)
plt.grid(True)
plt.show()

# %%
pd.DataFrame(payoffs).to_csv('../Plots/Data/moss/moss.csv')
